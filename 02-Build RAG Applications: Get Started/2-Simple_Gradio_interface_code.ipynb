# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-5.49.1-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/conda/lib/python3.12/site-packages (from gradio) (4.8.0)
# Requirement already satisfied: brotli>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from gradio) (1.1.0)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.121.0-py3-none-any.whl.metadata (28 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.6.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.13.3 (from gradio)
#   Downloading gradio_client-1.13.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /opt/conda/lib/python3.12/site-packages (from gradio) (0.28.1)
# Collecting huggingface-hub<2.0,>=0.33.5 (from gradio)
#   Downloading huggingface_hub-1.0.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: jinja2<4.0 in /opt/conda/lib/python3.12/site-packages (from gradio) (3.1.5)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /opt/conda/lib/python3.12/site-packages (from gradio) (3.0.2)
# Collecting numpy<3.0,>=1.0 (from gradio)
#   Downloading numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.11.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from gradio) (24.2)
# Collecting pandas<3.0,>=1.0 (from gradio)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting pillow<12.0,>=8.0 (from gradio)
#   Downloading pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /opt/conda/lib/python3.12/site-packages (from gradio) (2.10.6)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /opt/conda/lib/python3.12/site-packages (from gradio) (6.0.2)
# Collecting ruff>=0.9.3 (from gradio)
#   Downloading ruff-0.14.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /opt/conda/lib/python3.12/site-packages (from gradio) (0.13.2)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.20.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/conda/lib/python3.12/site-packages (from gradio) (4.12.2)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting fsspec (from gradio-client==1.13.3->gradio)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting websockets<16.0,>=13.0 (from gradio-client==1.13.3->gradio)
#   Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.49.3-py3-none-any.whl.metadata (6.4 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Downloading annotated_doc-0.0.3-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx<1.0,>=0.24.1->gradio) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.14.0)
# Collecting filelock (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting shellingham (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Collecting typer-slim (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading typer_slim-0.20.0-py3-none-any.whl.metadata (16 kB)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Collecting tzdata>=2022.7 (from pandas<3.0,>=1.0->gradio)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio) (2.27.2)
# Collecting click>=8.0.0 (from typer<1.0,>=0.12->gradio)
#   Downloading click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading gradio-5.49.1-py3-none-any.whl (63.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 MB 109.7 MB/s eta 0:00:0000:0100:01
# Downloading gradio_client-1.13.3-py3-none-any.whl (325 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading fastapi-0.121.0-py3-none-any.whl (109 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading huggingface_hub-1.0.1-py3-none-any.whl (503 kB)
# Downloading numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 53.3 MB/s eta 0:00:00:00:01
# Downloading orjson-3.11.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (136 kB)
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 50.2 MB/s eta 0:00:00:00:01
# Downloading pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 49.6 MB/s eta 0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.14.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 49.8 MB/s eta 0:00:00:00:01
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.49.3-py3-none-any.whl (74 kB)
# Downloading typer-0.20.0-py3-none-any.whl (47 kB)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading ffmpy-0.6.4-py3-none-any.whl (5.6 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading annotated_doc-0.0.3-py3-none-any.whl (5.5 kB)
# Downloading click-8.3.0-py3-none-any.whl (107 kB)
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 158.3 MB/s eta 0:00:00
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (182 kB)
# Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Downloading typer_slim-0.20.0-py3-none-any.whl (47 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pydub, websockets, tzdata, shellingham, semantic-version, ruff, python-multipart, pillow, orjson, numpy, mdurl, hf-xet, groovy, fsspec, filelock, ffmpy, click, annotated-doc, aiofiles, uvicorn, typer-slim, starlette, pandas, markdown-it-py, safehttpx, rich, huggingface-hub, fastapi, typer, gradio-client, gradio
# Successfully installed aiofiles-24.1.0 annotated-doc-0.0.3 click-8.3.0 fastapi-0.121.0 ffmpy-0.6.4 filelock-3.20.0 fsspec-2025.10.0 gradio-5.49.1 gradio-client-1.13.3 groovy-0.1.2 hf-xet-1.2.0 huggingface-hub-1.0.1 markdown-it-py-4.0.0 mdurl-0.1.2 numpy-2.3.4 orjson-3.11.4 pandas-2.3.3 pillow-11.3.0 pydub-0.25.1 python-multipart-0.0.20 rich-14.2.0 ruff-0.14.3 safehttpx-0.1.7 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.49.3 typer-0.20.0 typer-slim-0.20.0 tzdata-2025.2 uvicorn-0.38.0 websockets-15.0.1

# %%
import gradio as gr


def add_numbers(Num1, Num2):
    return Num1 + Num2

# Define the interface
demo = gr.Interface(
    fn=add_numbers, 
    inputs=[gr.Number(), gr.Number()], # Create two numerical input fields where users can enter numbers
    outputs=gr.Number() # Create numerical output fields
)

# Launch the interface
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * Running on public URL: https://e4ba286e6feeed12ed.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e4ba286e6feeed12ed.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

def Combine(a,b):
    return a + " " + b

demo=gr.Interface(fn=Combine, 
inputs=[gr.Textbox(label="Enter the first Sentence"),
gr.Textbox(label="enter the second sentence")],
outputs=gr.Textbox(label="Output"))

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * Running on public URL: https://4d1ff3855c6ee4e7bf.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4d1ff3855c6ee4e7bf.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

def sentence_builder(quantity, tech_worker_type, countries, place, activity_list, morning):
    return f"""The {quantity} {tech_worker_type}s from {" and ".join(countries)} went to the {place} where they {" and ".join(activity_list)} until the {"morning" if morning else "night"}"""

demo = gr.Interface(
    fn=sentence_builder,
    inputs=[
        gr.Slider(3, 20, value=4, step=1, label="Count", info="Choose between 3 and 20"),
        gr.Dropdown(
            ["Data Scientist", "Software Developer", "Software Engineer"], 
            label="tech_worker_type", 
            info="Will add more tech worker types later!"
        ),
        gr.CheckboxGroup(["Canada", "Japan", "France"], label="Countries", info="Where are they from?"),
        gr.Radio(["office", "restaurant", "meeting room"], label="Location", info="Where did they go?"),
        gr.Dropdown(
            ["partied", "brainstormed", "coded", "fixed bugs"], 
            value=["brainstormed", "fixed bugs"], 
            multiselect=True, 
            label="Activities", 
            info="Which activities did they perform?"
        ),
        gr.Checkbox(label="Morning", info="Did they do it in the morning?"),
    ],
    outputs="text",
    examples=[
        [3, "Software Developer", ["Canada", "Japan"], "restaurant", ["coded", "fixed bugs"], True],
        [4, "Data Scientist", ["Japan"], "office", ["brainstormed", "partied"], False],
        [10, "Software Engineer", ["Canada", "France"], "meeting room", ["brainstormed"], False],
        [8, "Data Scientist", ["France"], "restaurant", ["coded"], True],
    ]
)

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7866
# * Running on public URL: https://6493ccfdb46684049c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://6493ccfdb46684049c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip install ibm_watsonx_ai
# Out:
# Collecting ibm_watsonx_ai
#   Downloading ibm_watsonx_ai-1.4.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from ibm_watsonx_ai) (2.32.3)
# Requirement already satisfied: httpx<0.29,>=0.27 in /opt/conda/lib/python3.12/site-packages (from ibm_watsonx_ai) (0.28.1)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.12/site-packages (from ibm_watsonx_ai) (2.3.0)
# Collecting pandas<2.3.0,>=0.24.2 (from ibm_watsonx_ai)
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from ibm_watsonx_ai) (2024.12.14)
# Collecting lomond (from ibm_watsonx_ai)
#   Downloading lomond-0.3.3-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting tabulate (from ibm_watsonx_ai)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from ibm_watsonx_ai) (24.2)
# Collecting ibm-cos-sdk<2.15.0,>=2.12.0 (from ibm_watsonx_ai)
#   Downloading ibm_cos_sdk-2.14.3.tar.gz (58 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cachetools (from ibm_watsonx_ai)
#   Downloading cachetools-6.2.1-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx<0.29,>=0.27->ibm_watsonx_ai) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<0.29,>=0.27->ibm_watsonx_ai) (1.0.7)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx<0.29,>=0.27->ibm_watsonx_ai) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ibm_watsonx_ai) (0.14.0)
# Collecting ibm-cos-sdk-core==2.14.3 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm_watsonx_ai)
#   Downloading ibm_cos_sdk_core-2.14.3.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 68.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ibm-cos-sdk-s3transfer==2.14.3 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm_watsonx_ai)
#   Downloading ibm_cos_sdk_s3transfer-2.14.3.tar.gz (139 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jmespath<=1.0.1,>=0.10.0 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm_watsonx_ai)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in /opt/conda/lib/python3.12/site-packages (from ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm_watsonx_ai) (2.9.0.post0)
# Collecting requests (from ibm_watsonx_ai)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting urllib3 (from ibm_watsonx_ai)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas<2.3.0,>=0.24.2->ibm_watsonx_ai) (2.3.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas<2.3.0,>=0.24.2->ibm_watsonx_ai) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas<2.3.0,>=0.24.2->ibm_watsonx_ai) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->ibm_watsonx_ai) (3.4.1)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.12/site-packages (from lomond->ibm_watsonx_ai) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio->httpx<0.29,>=0.27->ibm_watsonx_ai) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /opt/conda/lib/python3.12/site-packages (from anyio->httpx<0.29,>=0.27->ibm_watsonx_ai) (4.12.2)
# Downloading ibm_watsonx_ai-1.4.4-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.0 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 157.2 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading cachetools-6.2.1-py3-none-any.whl (11 kB)
# Downloading lomond-0.3.3-py2.py3-none-any.whl (35 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Building wheels for collected packages: ibm-cos-sdk, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer
#   Building wheel for ibm-cos-sdk (setup.py) ... one
#   Created wheel for ibm-cos-sdk: filename=ibm_cos_sdk-2.14.3-py3-none-any.whl size=77292 sha256=9eff75e547590a5ae056e9de8983f9af0b67975eb5e395a252f96c563c857b40
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/cc/2f/6f/125918ad46d280d3bea58edf99f0757888ef6e7999db4b73b7
#   Building wheel for ibm-cos-sdk-core (setup.py) ... one
#   Created wheel for ibm-cos-sdk-core: filename=ibm_cos_sdk_core-2.14.3-py3-none-any.whl size=662156 sha256=6959466780415c6499e5b54f4e30c8aafbd854b82460911ad9886878568f89ca
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/f1/53/13/7c8fdeebdb847995d8ef349b4f695c595d8d31b30ae2a07ea2
#   Building wheel for ibm-cos-sdk-s3transfer (setup.py) ... one
#   Created wheel for ibm-cos-sdk-s3transfer: filename=ibm_cos_sdk_s3transfer-2.14.3-py3-none-any.whl size=90259 sha256=695bb2bbb421524399a225e3f78cb37d4b71fe24d9f4d37266e9d811c58e2253
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/0c/8b/10/0346c5a955b48b7fca50a8a42de309546b22899b7e8c1da8a5
# Successfully built ibm-cos-sdk ibm-cos-sdk-core ibm-cos-sdk-s3transfer
# Installing collected packages: urllib3, tabulate, lomond, jmespath, cachetools, requests, pandas, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer, ibm-cos-sdk, ibm_watsonx_ai
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.3.3
#     Uninstalling pandas-2.3.3:
#       Successfully uninstalled pandas-2.3.3
# Successfully installed cachetools-6.2.1 ibm-cos-sdk-2.14.3 ibm-cos-sdk-core-2.14.3 ibm-cos-sdk-s3transfer-2.14.3 ibm_watsonx_ai-1.4.4 jmespath-1.0.1 lomond-0.3.3 pandas-2.2.3 requests-2.32.5 tabulate-0.9.0 urllib3-2.5.0

# %%
# !pip install langchain_ibm
# Out:
# Collecting langchain_ibm
#   Downloading langchain_ibm-1.0.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting langchain-core<2.0.0,>=1.0.0 (from langchain_ibm)
#   Downloading langchain_core-1.0.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: ibm-watsonx-ai<2.0.0,>=1.3.37 in /opt/conda/lib/python3.12/site-packages (from langchain_ibm) (1.4.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.32.5)
# Requirement already satisfied: httpx<0.29,>=0.27 in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (0.28.1)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.5.0)
# Requirement already satisfied: pandas<2.3.0,>=0.24.2 in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.2.3)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2024.12.14)
# Requirement already satisfied: lomond in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (0.3.3)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (0.9.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (24.2)
# Requirement already satisfied: ibm-cos-sdk<2.15.0,>=2.12.0 in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.14.3)
# Requirement already satisfied: cachetools in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (6.2.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/conda/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ibm) (1.33)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.0.0->langchain_ibm)
#   Downloading langsmith-0.4.39-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/conda/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ibm) (2.10.6)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/conda/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ibm) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/conda/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ibm) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/conda/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ibm) (4.12.2)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (1.0.7)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (0.14.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.14.3 in /opt/conda/lib/python3.12/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.14.3)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.14.3 in /opt/conda/lib/python3.12/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.14.3)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /opt/conda/lib/python3.12/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in /opt/conda/lib/python3.12/site-packages (from ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.9.0.post0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain_ibm) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /opt/conda/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ibm) (3.11.4)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ibm)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ibm) (0.23.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.3.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_ibm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_ibm) (2.27.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (3.4.1)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.12/site-packages (from lomond->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio->httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (1.3.1)
# Downloading langchain_ibm-1.0.0-py3-none-any.whl (49 kB)
# Downloading langchain_core-1.0.2-py3-none-any.whl (469 kB)
# Downloading langsmith-0.4.39-py3-none-any.whl (397 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: requests-toolbelt, langsmith, langchain-core, langchain_ibm
# Successfully installed langchain-core-1.0.2 langchain_ibm-1.0.0 langsmith-0.4.39 requests-toolbelt-1.0.0

# %%
# Import necessary packages
from ibm_watsonx_ai.foundation_models import ModelInference
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai import Credentials
from langchain_ibm import WatsonxLLM
import gradio as gr

# Model and project settings
#model_id = 'mistralai/mixtral-8x7b-instruct-v01' # Specify the Mixtral 8x7B model
model_id = 'ibm/granite-3-3-8b-instruct' # Specify IBM's Granite 3.3 8B model

# Set necessary parameters
parameters = {
    GenParams.MAX_NEW_TOKENS: 256,  # Specify the max tokens you want to generate
    GenParams.TEMPERATURE: 0.5, # This randomness or creativity of the model's responses
}

project_id = "skills-network"

# Wrap up the model into WatsonxLLM inference
watsonx_llm = WatsonxLLM(
    model_id=model_id,
    url="https://us-south.ml.cloud.ibm.com",
    project_id=project_id,
    params=parameters,
)

# Function to generate a response from the model
def generate_response(prompt_txt):
    generated_response = watsonx_llm.invoke(prompt_txt)
    return generated_response

# Create Gradio interface
chat_application = gr.Interface(
    fn=generate_response,
    allow_flagging="never",
    inputs=gr.Textbox(label="Input", lines=2, placeholder="Type your question here..."),
    outputs=gr.Textbox(label="Output"),
    title="Watsonx.ai Chatbot",
    description="Ask any question and the chatbot will try to answer."
)

# Launch the app
chat_application.launch(share=True)
# Out:
# /opt/conda/lib/python3.12/site-packages/gradio/interface.py:415: UserWarning: The `allow_flagging` parameter in `Interface` is deprecated. Use `flagging_mode` instead.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7868
# * Running on public URL: https://df3e2b30cda0cc7c4d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://df3e2b30cda0cc7c4d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Import necessary packages
from ibm_watsonx_ai.foundation_models import ModelInference
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai import Credentials
from langchain_ibm import WatsonxLLM
import gradio as gr

# Model and project settings
#model_id = 'mistralai/mixtral-8x7b-instruct-v01' # Specify the Mixtral 8x7B model
model_id = 'ibm/granite-3-3-8b-instruct' # Specify IBM's Granite 3.3 8B model

# Set necessary parameters
parameters = {
    GenParams.MAX_NEW_TOKENS: 512,  # Specify the max tokens you want to generate
    GenParams.TEMPERATURE: 0.5, # This randomness or creativity of the model's responses
}

project_id = "skills-network"

# Wrap up the model into WatsonxLLM inference
watsonx_llm = WatsonxLLM(
    model_id=model_id,
    url="https://us-south.ml.cloud.ibm.com",
    project_id=project_id,
    params=parameters,
)

# Function to generate a response from the model
def generate_response(prompt_txt):
    generated_response = watsonx_llm.invoke(prompt_txt)
    return generated_response

# Create Gradio interface
chat_application = gr.Interface(
    fn=generate_response,
    allow_flagging="never",
    inputs=gr.Textbox(label="Input", lines=2, placeholder="Type your question here..."),
    outputs=gr.Textbox(label="Output"),
    title="Watsonx.ai Chatbot",
    description="Ask any question and the chatbot will try to answer."
)

# Launch the app
chat_application.launch(share=True)
# Out:
# /opt/conda/lib/python3.12/site-packages/gradio/interface.py:415: UserWarning: The `allow_flagging` parameter in `Interface` is deprecated. Use `flagging_mode` instead.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7869
# * Running on public URL: https://8fc6ef026660d1a421.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://8fc6ef026660d1a421.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
